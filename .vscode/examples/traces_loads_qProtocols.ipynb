# %%
import numpy as np
import serial
import time
import matplotlib.pyplot as plt
from IPython import display
plt.style.use("dark_background")

# %%
# %matplotlib widget

# %%
def parse_data(l:str):
    if len(l) < 10: return "", []
    if l[:5] != "Data:": return "", []
    s = l.split('\t')

    if len(s) < 2: return "", []
    _t = s[0].split(',')
    if len(_t) < 2: return "", []
    _type = _t[0][5:]
    _size = int(_t[1][7:])
    arr = np.fromstring(s[1], sep = ',', dtype=np.uint32)
    if _type == "ENV":
        env_type = np.bitwise_and(arr, 0xF000) >> 12
        env_read = np.bitwise_and(arr, 0x0FFF)
        env_time = np.bitwise_and(arr, 0xFFFF0000) >> 10
        leaftemp_t = env_time[env_type == 4]
        leaftemp = env_read[env_type == 4] / 10
        timestemp_t = env_time[env_type < 4]
        timestemp = env_type[env_type < 4]
        return "ENV", [timestemp_t, timestemp, leaftemp_t, leaftemp]
    elif _type in ["Fluo", "Fluoref", "SUN", "leaf", "730", "730ref"]:
        return _type, [arr]
    else:
        print(_type)

    return "", []

def gen_cmd_arr_line(mode:int, ir:int, num:int, freq:int, actinic:int, sub:int)->list:
    return [mode, ir, num//256, num%256, freq//256, freq%256, actinic, sub]

def ambit_run_arr(cmd_str, port = "COM31"):
    timeout = 60
    s = ''
    _l = 0
    result = {"env_t0": time.time()}

    with serial.Serial(port, baudrate=115200) as ser:
        t0 = time.time()
        ser.write(cmd_str.encode())
        while time.time() - t0 < timeout:
            try:
                if ser.in_waiting > 1:
                    c = ser.read()
                    if (c > bytes([0])) and (c < bytes([128])):
                        s += c.decode()
                        _l += 1
                        if (c == b"\n") or (c == b"\r"):
                            l = s
                            s = ''
                            _l = 0
                            if l[:-1] == "BAD COMMAND":
                                timeout = 1
                                continue
                            if l[:-1] == "Data sent":
                                timeout = .1
                                continue
                            #print(l)
                            d_type, data = parse_data(l)
                            if d_type == "ENV":
                                result.update({"env_stamp_t": data[0], "env_stamp": data[1], "env_leaf_t": data[2], "env_leaf": data[3]})
                            elif d_type != "":
                                result.update({d_type: data[0][:-1]})
                else:
                    time.sleep(.1)
            except KeyboardInterrupt:
                break
    return result

def calc_arr_param(cmd: list, persist:bool):
    cmd_arr = np.reshape(cmd, (-1, 8))
    arr_length = cmd_arr.shape[0]
    cmd_str = "arrun," + str(arr_length) + "," + str(persist) + ","+ str(cmd)[1:-1] + ",\n"
    cmd_str = cmd_str.replace(" ", "")

    num_pts = cmd_arr[:, 2] * 256 + cmd_arr[:, 3]
    mea_feq = 1 / (cmd_arr[:, 4] * 256 + cmd_arr[:, 5])
    _t, mea_tml = 0, []
    for _n, _f in zip(num_pts, mea_feq):
        mea_tml += (np.arange(_n) * _f + _t).tolist()
        _t = mea_tml[-1]
    mea_tml = np.array(mea_tml) * 0.854
    return cmd_str, mea_tml

# %%
class ambit_run():
    def __init__(self, persist:bool = False) -> None:
        self.cmd_list = []
        self.led_persist = int(persist)
        
    def add(self, mode:int = 2, ir:int = 0, num:int = 100, freq:int = 100, actinic:int = 0, sub:int = 1):
        self.cmd_list += [mode, ir, num//256, num%256, freq//256, freq%256, actinic, sub]
        return
    def run(self):
        cmd_str, self.mea_tml = calc_arr_param(self.cmd_list, self.led_persist)
        self.result = {"env_tl": self.mea_tml, "env_t0": time.time()}
        self.result.update(ambit_run_arr(cmd_str))
        return self.result

    def plot(self):
        result = self.result
        mea_tml = self.mea_tml
        plot_list = [_k for _k in result.keys() if _k[:4] != "env_"]
        fig, axes = plt.subplots(1, len(plot_list) + 1, sharex = True, figsize = (20, 6))
        for n, _p in enumerate(plot_list):
            axes[n + 1].plot(mea_tml[1:], result[_p][1:])
            axes[n + 1].set_title(_p)
        axes[0].plot(mea_tml[1:], (result["Fluo"]/ result["Fluoref"])[1:])
        # axes[0].plot(result['env_stamp_t'][:-1]/854, result['env_stamp'][:-1]* np.mean((result["Fluo"]/ result["Fluoref"])[1:]) + .1)
        ax = axes[0].twinx()
        ax.plot(result['env_leaf_t']/1000, result['env_leaf'], 'r.-')

# %%
def set_led(port = "COM31"):
    cmd_str = "set_currents,110,0,80,\n"
    #cmd_str = "set_gains,1,4,4,1,5,5,\n"

    s = ""
    with serial.Serial(port, baudrate=115200) as ser:
        t0 = time.time()
        ser.write(cmd_str.encode())
        while time.time() - t0 < 1:
            if ser.in_waiting > 0:
                c = ser.read()
                if (c > bytes([0])) and (c < bytes([128])):
                    s += c.decode()
                    if (c == b"\n") or (c == b"\r"):
                        l = s
                        s = ''
                        print(l)


set_led()
# Out:
# cmd: set_currents
#
# Currents set to 110, 0, 80

# %%
IR1 = ambit_run(False)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 0, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 5, sub = 1)
IR1.add(mode = 1, ir = 1, num = 20, freq = 2, actinic = 5, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 5, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 0, sub = 1)
IR1.run()
IR1.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:464, in FigureManagerWebAgg.handle_json(self, content)
#     463 def handle_json(self, content):
# --> 464     self.canvas.handle_event(content)
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:294, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     291 guiEvent = event.get('guiEvent')
#     292 if e_type in ['button_press', 'button_release']:
#     293     MouseEvent(e_type + '_event', self, x, y, button,
# --> 294                modifiers=modifiers, guiEvent=guiEvent)._process()
#     295 elif e_type == 'dblclick':
#     296     MouseEvent('button_press_event', self, x, y, button, dblclick=True,
#     297                modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:1271, in Event._process(self)
#    1269 def _process(self):
#    1270     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1271     self.canvas.callbacks.process(self.name, self)
#    1272     self._guiEvent_deleted = True
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File c:\Users\hjcbj\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2567, in button_press_handler(event, canvas, toolbar)
#    2565     toolbar = canvas.toolbar
#    2566 if toolbar is not None:
# -> 2567     button_name = str(MouseButton(event.button))
#    2568     if button_name in rcParams['keymap.back']:
#    2569         toolbar.back()
#
# File c:\Users\hjcbj\anaconda3\Lib\enum.py:712, in EnumType.__call__(cls, value, names, module, qualname, type, start, boundary)
#     687 """
#     688 Either returns an existing member, or creates a new enum class.
#     689
#    (...)
#     709 `type`, if set, will be mixed in as the first base class.
#     710 """
#     711 if names is None:  # simple value lookup
# --> 712     return cls.__new__(cls, value)
#     713 # otherwise, functional API: we're creating a new Enum type
#     714 return cls._create_(
#     715         value,
#     716         names,
#    (...)
#     721         boundary=boundary,
#     722         )
#
# File c:\Users\hjcbj\anaconda3\Lib\enum.py:1128, in Enum.__new__(cls, value)
#    1126 ve_exc = ValueError("%r is not a valid %s" % (value, cls.__qualname__))
#    1127 if result is None and exc is None:
# -> 1128     raise ve_exc
#    1129 elif exc is None:
#    1130     exc = TypeError(
#    1131             'error in %s._missing_: returned %r instead of None or a valid member'
#    1132             % (cls.__name__, result)
#    1133             )
#
# ValueError: 5 is not a valid MouseButton

# %%
IR1 = ambit_run(False)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 0, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 5, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 5, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 5, sub = 1)
IR1.add(mode = 1, ir = 0, num = 20, freq = 2, actinic = 0, sub = 1)
IR1.run()
IR1.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
MPF1 = ambit_run(True)
MPF1.add(num = 50, freq = 50, actinic=0)
MPF1.add(num = 50, freq = 50, actinic=10)
MPF1.add(num = 50, freq = 50, actinic=0)

MPF1.add(num = 50, freq = 10, actinic=0)


MPF1.add(num = 50, freq = 50, actinic=0)
MPF1.add(num = 50, freq = 50, actinic=10)
MPF1.add(num = 50, freq = 50, actinic=0)

MPF1.run()
MPF1.plot()

# %%
plt.figure()
plt.plot(MPF1.result['Fluo']/MPF1.result['Fluoref'])

# %%
MPF1 = ambit_run(True)
MPF1.add(num = 10, freq = 5, actinic=0)
MPF1.add(num = 40, freq = 100, actinic=250)  # 0.4s max

MPF1.add(num = 10, freq = 100, actinic=200)  # 0.1s 
MPF1.add(num = 10, freq = 100, actinic=120)  # 0.1s 
MPF1.add(num = 10, freq = 100, actinic=100)  # 0.1s 
MPF1.add(num = 10, freq = 100, actinic=80)  # 0.1s 
MPF1.add(num = 10, freq = 100, actinic=60)  # 0.1s 

MPF1.add(num = 40, freq = 100, actinic=240)
MPF1.add(num = 25, freq = 100, actinic=0)
MPF1.add(num = 50, freq = 10, actinic=0)

MPF1.run()
MPF1.plot()

# %%
actinic_setting = 10

# %%
MPF2 = ambit_run(True)
MPF2.add(num = 25, freq = 100, actinic=250)
MPF2.add(num = 25, freq = 100, actinic=200)
MPF2.add(num = 25, freq = 100, actinic=150)
MPF2.add(num = 25, freq = 100, actinic=100)
MPF2.add(num = 25, freq = 100, actinic=250)
MPF2.add(num = 25, freq = 100, actinic=actinic_setting)
# ret = MPF2.run()
# MPF2.plot()

# %%
MPF3 = ambit_run(True)
MPF3.add(num = 25, freq = 100, actinic=250)
MPF3.add(num = 25, freq = 100, actinic=200)
MPF3.add(num = 25, freq = 100, actinic=150)
MPF3.add(num = 25, freq = 100, actinic=100)
MPF3.add(num = 25, freq = 100, actinic=250)
MPF3.add(num = 25, freq = 100, actinic=0)
# ret = MPF3.run()
# MPF3.plot()

# %%
RGF1 = ambit_run(True)
RGF1.add(num = 50, freq = 100, actinic=250)
RGF1.add(num = 50, freq = 100, actinic=0)

RGF2 = ambit_run(True)
RGF2.add(num = 50, freq = 100, actinic=250)
RGF2.add(num = 50, freq = 100, actinic=actinic_setting)

# %%
ACT1 = ambit_run(True)
ACT1.add(num=100, freq = 20, actinic=actinic_setting)

AMB1 = ambit_run()
AMB1.add(num = 100, freq = 20, actinic=0)
AMB1.add(num = 50, freq = 100, actinic=250)
AMB1.add(num = 50, freq = 100, actinic=0)
AMB1.add(num = 100, freq = 20, actinic=0)

AMB2 = ambit_run()
AMB2.add(num=100, freq = 10, actinic=0)
AMB2.add(num = 50, freq = 100, actinic=250)
AMB2.add(num = 50, freq = 100, actinic=0)
AMB2.add(num=100, freq = 10, actinic=0)

AMB3 = ambit_run()
AMB3.add(num=100, freq = 5, actinic=0)
AMB3.add(num = 50, freq = 100, actinic=250)
AMB3.add(num = 50, freq = 100, actinic=0)
AMB3.add(num=100, freq = 5, actinic=0)

AMB4 = ambit_run()
AMB4.add(num=60, freq = 1, actinic=0)
AMB4.add(num = 50, freq = 100, actinic=250)
AMB4.add(num = 50, freq = 100, actinic=0)
AMB4.add(num=60, freq = 1, actinic=0)

# %%
runlist = [MPF1] + [ACT1, RGF2] * 4 + [AMB1] * 2 + [AMB2] * 2 + [AMB3] * 2 + [AMB4] * 2
fig, axes = plt.subplots(1, 5, sharex = True, figsize = (20, 6))
ax = axes[0].twinx()
results = []
for n in runlist:
    ret = n.run()
    results.append(ret)
    _tl = ret['env_tl']
    _TL = _tl + ret['env_t0']
    plot_list = [_k for _k in ret.keys() if _k[:4] != "env_"]
    for n, _p in enumerate(plot_list):
        axes[n + 1].plot(_TL[1:], ret[_p][1:])
        axes[n + 1].set_title(_p)
    axes[0].plot(_TL[1:], (ret["Fluo"]/ ret["Fluoref"])[1:])
    # axes[0].plot(result['env_stamp_t'][:-1]/854, result['env_stamp'][:-1]* np.mean((result["Fluo"]/ result["Fluoref"])[1:]) + .1)
    ax.plot(ret['env_leaf_t']/1000 + ret['env_t0'], ret['env_leaf'], 'r.')
    display.display(fig)
    display.clear_output(True)

# %%
fig, axes = plt.subplots(1, 1, sharex = True, figsize = (16, 6), facecolor = [0, 0, 0, 0])
ax = axes.twinx()
for ret in results:
    _tl = ret['env_tl']
    _TL = _tl + ret['env_t0']
    axes.plot(_TL[1:], (ret["Fluo"]/ ret["Fluoref"])[1:])
    
    ax.plot(ret['env_leaf_t']/1000 + ret['env_t0'], ret['env_leaf'], 'r.')
